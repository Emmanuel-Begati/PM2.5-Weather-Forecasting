# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.metrics import RootMeanSquaredError
from statsmodels.tsa.seasonal import seasonal_decompose
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from datetime import datetime

# %%
# Load the datasets
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
# Inspecting the first few rows of the dataset to understand its structure.
print("Training Data Overview:")
train.head()
# Out:
# Training Data Overview:
#    No      DEWP      TEMP      PRES       Iws        Is        Ir  \
# 0   1 -1.580878 -1.922250  0.443328 -0.441894 -0.069353 -0.137667
# 1   2 -1.580878 -2.004228  0.345943 -0.379306 -0.069353 -0.137667
# 2   3 -1.580878 -1.922250  0.248559 -0.343514 -0.069353 -0.137667
# 3   4 -1.580878 -2.168183  0.248559 -0.280926 -0.069353 -0.137667
# 4   5 -1.511594 -2.004228  0.151174 -0.218339 -0.069353 -0.137667
#
#               datetime   cbwd_NW   cbwd_SE   cbwd_cv  pm2.5
# 0  2010-01-01 00:00:00  1.448138 -0.732019 -0.522096    NaN
# 1  2010-01-01 01:00:00  1.448138 -0.732019 -0.522096    NaN
# 2  2010-01-01 02:00:00  1.448138 -0.732019 -0.522096    NaN
# 3  2010-01-01 03:00:00  1.448138 -0.732019 -0.522096    NaN
# 4  2010-01-01 04:00:00  1.448138 -0.732019 -0.522096    NaN

# %%
train.describe()
# Out:
#                  No          DEWP          TEMP          PRES           Iws  \
# count  30676.000000  30676.000000  30676.000000  30676.000000  30676.000000
# mean   15338.500000     -0.029431     -0.062712      0.013612      0.030542
# std     8855.542765      0.994087      1.015193      1.008991      1.018337
# min        1.000000     -2.135153     -2.578070     -2.380821     -0.468688
# 25%     7669.750000     -0.888034     -0.938521     -0.822670     -0.441894
# 50%    15338.500000     -0.056622      0.045209     -0.043595     -0.352512
# 75%    23007.250000      0.913358      0.864984      0.832865      0.005216
# max    30676.000000      1.814055      2.340578      2.877939     11.231956
#
#                  Is            Ir       cbwd_NW       cbwd_SE       cbwd_cv  \
# count  30676.000000  30676.000000  30676.000000  30676.000000  30676.000000
# mean       0.016992      0.011253      0.016193      0.005833     -0.025008
# std        1.087278      1.063811      1.006001      1.001847      0.982122
# min       -0.069353     -0.137667     -0.690542     -0.732019     -0.522096
# 25%       -0.069353     -0.137667     -0.690542     -0.732019     -0.522096
# 50%       -0.069353     -0.137667     -0.690542     -0.732019     -0.522096
# 75%       -0.069353     -0.137667      1.448138      1.366085     -0.522096
# max       35.439859     25.288745      1.448138      1.366085      1.915355
#
#               pm2.5
# count  28755.000000
# mean     100.793427
# std       93.144433
# min        0.000000
# 25%       29.000000
# 50%       75.000000
# 75%      142.000000
# max      994.000000

# %% [markdown]
# ## Cleaning up the data
#
# To clean the data I did the following:
# 1. Converted values in the datetime column into pandas datetime objects.
# 2. Set the datetime column as the index for the data.
# 3. Filled in the missing values by interpolating values within the dataset as interpolation provides a more accurate estimate based on neighbouring values. However for values at the beginning or end of the dataset that cannot be interpolated, I am going to fill them with the mean.

# %%
# Ensure 'datetime' column is in datetime format
train['datetime'] = pd.to_datetime(train['datetime'])
test['datetime'] = pd.to_datetime(test['datetime'])

# Set the 'datetime' column as the index for better time-series handling
train.set_index('datetime', inplace=True)
test.set_index('datetime', inplace=True)

# Fill in missing values
# First I am going to interpolate missing values in the middle rows
# Then, I am going to fill the missing values at the beginning of the dataset
train['pm2.5'] = train['pm2.5'].fillna(train['pm2.5'].interpolate()).fillna(train['pm2.5'].mean())

test.fillna(test.interpolate(), inplace=True)

# %%
plt.hist(train['pm2.5'])
plt.show() #Just to see the distribution of the PM 2.5

# %%
# Extract different date fields
train['year'] = train.index.year
train['month'] = train.index.month
train.reset_index(inplace=True)
train['week'] = train['datetime'].dt.isocalendar().week
train['day_of_year'] = train['datetime'].dt.day_of_year
train['hour'] = train['datetime'].dt.hour
train['day'] = train['datetime'].dt.dayofweek
train['day_str'] = train['datetime'].dt.strftime('%a')
train['year_month'] = train['datetime'].dt.strftime('%Y_%m')
train.set_index('datetime', inplace=True)

train.head()
# Out:
#                      No      DEWP      TEMP      PRES       Iws        Is  \
# datetime
# 2010-01-01 00:00:00   1 -1.580878 -1.922250  0.443328 -0.441894 -0.069353
# 2010-01-01 01:00:00   2 -1.580878 -2.004228  0.345943 -0.379306 -0.069353
# 2010-01-01 02:00:00   3 -1.580878 -1.922250  0.248559 -0.343514 -0.069353
# 2010-01-01 03:00:00   4 -1.580878 -2.168183  0.248559 -0.280926 -0.069353
# 2010-01-01 04:00:00   5 -1.511594 -2.004228  0.151174 -0.218339 -0.069353
#
#                            Ir   cbwd_NW   cbwd_SE   cbwd_cv       pm2.5  year  \
# datetime
# 2010-01-01 00:00:00 -0.137667  1.448138 -0.732019 -0.522096  100.793427  2010
# 2010-01-01 01:00:00 -0.137667  1.448138 -0.732019 -0.522096  100.793427  2010
# 2010-01-01 02:00:00 -0.137667  1.448138 -0.732019 -0.522096  100.793427  2010
# 2010-01-01 03:00:00 -0.137667  1.448138 -0.732019 -0.522096  100.793427  2010
# 2010-01-01 04:00:00 -0.137667  1.448138 -0.732019 -0.522096  100.793427  2010
#
#                      month  week  day_of_year  hour  day day_str year_month
# datetime
# 2010-01-01 00:00:00      1    53            1     0    4     Fri    2010_01
# 2010-01-01 01:00:00      1    53            1     1    4     Fri    2010_01
# 2010-01-01 02:00:00      1    53            1     2    4     Fri    2010_01
# 2010-01-01 03:00:00      1    53            1     3    4     Fri    2010_01
# 2010-01-01 04:00:00      1    53            1     4    4     Fri    2010_01

# %%
columns_to_drop = [
  'year',
  'month',
  'week',
  'day_of_year',
  'hour',
  'day',
  'day_str',
  'year_month',
  'No',
  'Is',
  'Ir',
  'cbwd_NW',
  'cbwd_SE',
  'cbwd_cv'
]

train = train.drop(columns_to_drop, axis=1)

# %%
X = train.drop('pm2.5', axis=1)
y = train['pm2.5']

# %%
# Reshape data for LSTM input
# LSTM models require data in the shape (samples, timesteps, features).
# Here, the data is reshaped to add a "timesteps" dimension.
X = np.expand_dims(X, axis=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2  # Import l2 regularizer
from tensorflow.keras.metrics import RootMeanSquaredError

# Define the model
model = Sequential([
    LSTM(128, activation='relu', dropout=0.2, return_sequences=True, 
         kernel_regularizer=l2(0.01), input_shape=(X.shape[1], X.shape[2])),
    BatchNormalization(),
    LSTM(64, activation='relu', dropout=0.2, kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dense(32, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.2),
    Dense(16, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.2),
    Dense(1)
])

# Compile the model
optimizer = Adam(learning_rate=0.01)
model.compile(
    optimizer=optimizer,
    loss='mse',
    metrics=[RootMeanSquaredError()]
)

# Display the model architecture
model.summary()
# Out:
# C:\Users\begat\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 1, 128)         │        68,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 120,129 (469.25 KB)
#  Trainable params: 120,129 (469.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

# Train the model
history = model.fit(
    X, y,
    epochs=100,  # Increase the number of epochs
    batch_size=32,  # Adjust batch size
    validation_split=0.2,  # Use a validation set
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 9029.1104 - root_mean_squared_error: 94.3471 - val_loss: 9223.6289 - val_root_mean_squared_error: 95.9935
# Epoch 2/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6779.7144 - root_mean_squared_error: 82.2617 - val_loss: 7582.8657 - val_root_mean_squared_error: 87.0012
# Epoch 3/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6916.6387 - root_mean_squared_error: 83.0742 - val_loss: 7996.3701 - val_root_mean_squared_error: 89.3423
# Epoch 4/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6707.4497 - root_mean_squared_error: 81.8090 - val_loss: 8436.8877 - val_root_mean_squared_error: 91.7803
# Epoch 5/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6709.4492 - root_mean_squared_error: 81.8170 - val_loss: 8022.9629 - val_root_mean_squared_error: 89.5013
# Epoch 6/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6350.9819 - root_mean_squared_error: 79.5952 - val_loss: 8263.9521 - val_root_mean_squared_error: 90.8394
# Epoch 7/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6504.6523 - root_mean_squared_error: 80.5677 - val_loss: 7404.6709 - val_root_mean_squared_error: 85.9791
# Epoch 8/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6272.6455 - root_mean_squared_error: 79.1189 - val_loss: 7667.1396 - val_root_mean_squared_error: 87.4902
# Epoch 9/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6318.5918 - root_mean_squared_error: 79.4078 - val_loss: 7673.7261 - val_root_mean_squared_error: 87.5309
# Epoch 10/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6310.4424 - root_mean_squared_error: 79.3539 - val_loss: 7287.5312 - val_root_mean_squared_error: 85.2966
# Epoch 11/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6298.4517 - root_mean_squared_error: 79.2802 - val_loss: 7133.2100 - val_root_mean_squared_error: 84.3880
# Epoch 12/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6144.8823 - root_mean_squared_error: 78.2972 - val_loss: 7825.3936 - val_root_mean_squared_error: 88.3952
# Epoch 13/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6342.2188 - root_mean_squared_error: 79.5395 - val_loss: 7177.3477 - val_root_mean_squared_error: 84.6487
# Epoch 14/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6144.6436 - root_mean_squared_error: 78.2992 - val_loss: 7421.7197 - val_root_mean_squared_error: 86.0782
# Epoch 15/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6129.5166 - root_mean_squared_error: 78.1965 - val_loss: 7930.3994 - val_root_mean_squared_error: 88.9812
# Epoch 16/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6251.0239 - root_mean_squared_error: 78.9624 - val_loss: 7379.9033 - val_root_mean_squared_error: 85.8289
# Epoch 17/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5965.7246 - root_mean_squared_error: 77.1288 - val_loss: 7567.9570 - val_root_mean_squared_error: 86.9157
# Epoch 18/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5957.8872 - root_mean_squared_error: 77.0849 - val_loss: 7123.2046 - val_root_mean_squared_error: 84.3180
# Epoch 19/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6089.7290 - root_mean_squared_error: 77.9288 - val_loss: 7694.3994 - val_root_mean_squared_error: 87.6356
# Epoch 20/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6059.6255 - root_mean_squared_error: 77.7443 - val_loss: 7852.6851 - val_root_mean_squared_error: 88.5302
# Epoch 21/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6201.2764 - root_mean_squared_error: 78.6310 - val_loss: 7197.1367 - val_root_mean_squared_error: 84.7430
# Epoch 22/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6077.9126 - root_mean_squared_error: 77.8484 - val_loss: 7818.8228 - val_root_mean_squared_error: 88.3338
# Epoch 23/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6055.3745 - root_mean_squared_error: 77.6965 - val_loss: 8069.4595 - val_root_mean_squared_error: 89.7371
# Epoch 24/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6036.4707 - root_mean_squared_error: 77.5790 - val_loss: 7340.5415 - val_root_mean_squared_error: 85.5786
# Epoch 25/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6289.6895 - root_mean_squared_error: 79.1738 - val_loss: 7635.6826 - val_root_mean_squared_error: 87.2843
# Epoch 26/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5884.9189 - root_mean_squared_error: 76.5841 - val_loss: 7896.2471 - val_root_mean_squared_error: 88.7601
# Epoch 27/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5974.7920 - root_mean_squared_error: 77.1744 - val_loss: 7249.2866 - val_root_mean_squared_error: 85.0374
# Epoch 28/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6051.8618 - root_mean_squared_error: 77.6675 - val_loss: 7945.8716 - val_root_mean_squared_error: 89.0392
# Epoch 29/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5723.2515 - root_mean_squared_error: 75.4913 - val_loss: 7533.0508 - val_root_mean_squared_error: 86.6845
# Epoch 30/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5966.3555 - root_mean_squared_error: 77.1119 - val_loss: 7495.5991 - val_root_mean_squared_error: 86.4676
# Epoch 31/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6123.0444 - root_mean_squared_error: 78.1229 - val_loss: 7640.5664 - val_root_mean_squared_error: 87.3007
# Epoch 32/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5901.9863 - root_mean_squared_error: 76.6794 - val_loss: 7722.9722 - val_root_mean_squared_error: 87.7682
# Epoch 33/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5959.9370 - root_mean_squared_error: 77.0507 - val_loss: 7266.2192 - val_root_mean_squared_error: 85.1253
# Epoch 34/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6178.0298 - root_mean_squared_error: 78.4598 - val_loss: 7800.5840 - val_root_mean_squared_error: 88.2087
# Epoch 35/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6002.9316 - root_mean_squared_error: 77.3360 - val_loss: 7678.9595 - val_root_mean_squared_error: 87.5147
# Epoch 36/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5820.1450 - root_mean_squared_error: 76.1460 - val_loss: 7743.4653 - val_root_mean_squared_error: 87.8836
# Epoch 37/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5897.0410 - root_mean_squared_error: 76.6362 - val_loss: 7780.1147 - val_root_mean_squared_error: 88.0912
# Epoch 38/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5981.5308 - root_mean_squared_error: 77.1866 - val_loss: 7734.8853 - val_root_mean_squared_error: 87.8338
# Epoch 39/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5927.4375 - root_mean_squared_error: 76.8519 - val_loss: 7231.4839 - val_root_mean_squared_error: 84.9191
# Epoch 40/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6131.0684 - root_mean_squared_error: 78.1554 - val_loss: 7660.7749 - val_root_mean_squared_error: 87.4068
# Epoch 41/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6081.3809 - root_mean_squared_error: 77.8238 - val_loss: 7531.2134 - val_root_mean_squared_error: 86.6617
# Epoch 42/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5965.3350 - root_mean_squared_error: 77.0932 - val_loss: 7624.8369 - val_root_mean_squared_error: 87.1986
# Epoch 43/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5812.4624 - root_mean_squared_error: 76.0926 - val_loss: 7930.8096 - val_root_mean_squared_error: 88.9333
# Epoch 44/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5904.2256 - root_mean_squared_error: 76.6653 - val_loss: 7526.8774 - val_root_mean_squared_error: 86.6300
# Epoch 45/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5828.3818 - root_mean_squared_error: 76.1886 - val_loss: 7496.6978 - val_root_mean_squared_error: 86.4572
# Epoch 46/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6105.9243 - root_mean_squared_error: 77.9848 - val_loss: 7443.3975 - val_root_mean_squared_error: 86.1482
# Epoch 47/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6019.0269 - root_mean_squared_error: 77.4292 - val_loss: 7422.1104 - val_root_mean_squared_error: 86.0249
# Epoch 48/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6090.7227 - root_mean_squared_error: 77.8926 - val_loss: 7649.0698 - val_root_mean_squared_error: 87.3336
# Epoch 49/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6057.3213 - root_mean_squared_error: 77.6789 - val_loss: 7849.6250 - val_root_mean_squared_error: 88.4733
# Epoch 50/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5960.1084 - root_mean_squared_error: 77.0366 - val_loss: 7778.3506 - val_root_mean_squared_error: 88.0708
# Epoch 51/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5792.0459 - root_mean_squared_error: 75.9487 - val_loss: 8089.7798 - val_root_mean_squared_error: 89.8178
# Epoch 52/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6020.7402 - root_mean_squared_error: 77.4414 - val_loss: 7610.6919 - val_root_mean_squared_error: 87.1094
# Epoch 53/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5854.3569 - root_mean_squared_error: 76.3250 - val_loss: 7580.3188 - val_root_mean_squared_error: 86.9334
# Epoch 54/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6115.9004 - root_mean_squared_error: 78.0314 - val_loss: 7510.0889 - val_root_mean_squared_error: 86.5280
# Epoch 55/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6026.3481 - root_mean_squared_error: 77.4696 - val_loss: 7031.0718 - val_root_mean_squared_error: 83.7122
# Epoch 56/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5934.9922 - root_mean_squared_error: 76.8841 - val_loss: 7921.7666 - val_root_mean_squared_error: 88.8726
# Epoch 57/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6126.5522 - root_mean_squared_error: 78.0893 - val_loss: 7897.8677 - val_root_mean_squared_error: 88.7350
# Epoch 58/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5939.3140 - root_mean_squared_error: 76.8909 - val_loss: 7763.5449 - val_root_mean_squared_error: 87.9733
# Epoch 59/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5922.8936 - root_mean_squared_error: 76.7919 - val_loss: 7405.5640 - val_root_mean_squared_error: 85.9128
# Epoch 60/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 5996.5396 - root_mean_squared_error: 77.2738 - val_loss: 7555.7251 - val_root_mean_squared_error: 86.7832
# Epoch 61/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5980.8940 - root_mean_squared_error: 77.1637 - val_loss: 7745.1357 - val_root_mean_squared_error: 87.8667
# Epoch 62/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5997.6768 - root_mean_squared_error: 77.2758 - val_loss: 7771.0181 - val_root_mean_squared_error: 88.0130
# Epoch 63/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5809.5518 - root_mean_squared_error: 76.0484 - val_loss: 7467.1963 - val_root_mean_squared_error: 86.2689
# Epoch 64/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6203.4546 - root_mean_squared_error: 78.5756 - val_loss: 7743.1069 - val_root_mean_squared_error: 87.8519
# Epoch 65/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5964.4668 - root_mean_squared_error: 77.0604 - val_loss: 7277.8174 - val_root_mean_squared_error: 85.1618
# Epoch 66/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6124.2031 - root_mean_squared_error: 78.0799 - val_loss: 7742.1016 - val_root_mean_squared_error: 87.8435
# Epoch 67/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6079.3301 - root_mean_squared_error: 77.7976 - val_loss: 7613.6543 - val_root_mean_squared_error: 87.1094
# Epoch 68/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6167.1318 - root_mean_squared_error: 78.3466 - val_loss: 7729.9517 - val_root_mean_squared_error: 87.7722
# Epoch 69/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5898.7456 - root_mean_squared_error: 76.6310 - val_loss: 7386.5063 - val_root_mean_squared_error: 85.7921
# Epoch 70/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5921.1680 - root_mean_squared_error: 76.7731 - val_loss: 7555.4751 - val_root_mean_squared_error: 86.7711
# Epoch 71/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5845.3057 - root_mean_squared_error: 76.2762 - val_loss: 7718.4009 - val_root_mean_squared_error: 87.7030
# Epoch 72/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6202.7842 - root_mean_squared_error: 78.4810 - val_loss: 7768.2251 - val_root_mean_squared_error: 87.9882
# Epoch 73/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5971.5591 - root_mean_squared_error: 77.0979 - val_loss: 7207.0176 - val_root_mean_squared_error: 84.7372
# Epoch 74/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5992.2954 - root_mean_squared_error: 77.2356 - val_loss: 7349.7690 - val_root_mean_squared_error: 85.5777
# Epoch 75/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5810.9229 - root_mean_squared_error: 76.0512 - val_loss: 7387.1484 - val_root_mean_squared_error: 85.7948
# Epoch 76/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5766.1719 - root_mean_squared_error: 75.7532 - val_loss: 7743.8579 - val_root_mean_squared_error: 87.8486
# Epoch 77/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5890.7725 - root_mean_squared_error: 76.5672 - val_loss: 7120.0210 - val_root_mean_squared_error: 84.2212
# Epoch 78/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5995.2949 - root_mean_squared_error: 77.2294 - val_loss: 8132.2290 - val_root_mean_squared_error: 90.0299
# Epoch 79/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5914.3140 - root_mean_squared_error: 76.7207 - val_loss: 7414.0073 - val_root_mean_squared_error: 85.9467
# Epoch 80/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5894.5493 - root_mean_squared_error: 76.5958 - val_loss: 7467.2417 - val_root_mean_squared_error: 86.2562
# Epoch 81/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5859.9692 - root_mean_squared_error: 76.3375 - val_loss: 7664.6699 - val_root_mean_squared_error: 87.3925
# Epoch 82/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6058.3867 - root_mean_squared_error: 77.6442 - val_loss: 7823.5449 - val_root_mean_squared_error: 88.2955
# Epoch 83/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5911.4512 - root_mean_squared_error: 76.6974 - val_loss: 7579.6162 - val_root_mean_squared_error: 86.8991
# Epoch 84/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5869.5469 - root_mean_squared_error: 76.4207 - val_loss: 7456.6929 - val_root_mean_squared_error: 86.1906
# Epoch 85/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5878.4941 - root_mean_squared_error: 76.4786 - val_loss: 7639.6499 - val_root_mean_squared_error: 87.2462
# Epoch 86/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5909.9282 - root_mean_squared_error: 76.6863 - val_loss: 7425.6621 - val_root_mean_squared_error: 86.0098
# Epoch 87/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5813.1528 - root_mean_squared_error: 76.0540 - val_loss: 7507.4902 - val_root_mean_squared_error: 86.4818
# Epoch 88/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5878.3081 - root_mean_squared_error: 76.4683 - val_loss: 8061.4453 - val_root_mean_squared_error: 89.6265
# Epoch 89/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5800.5552 - root_mean_squared_error: 75.9558 - val_loss: 7595.1113 - val_root_mean_squared_error: 86.9848
# Epoch 90/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6031.0884 - root_mean_squared_error: 77.4611 - val_loss: 7665.8936 - val_root_mean_squared_error: 87.3893
# Epoch 91/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5994.5317 - root_mean_squared_error: 77.2258 - val_loss: 8102.4609 - val_root_mean_squared_error: 89.8541
# Epoch 92/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5946.9658 - root_mean_squared_error: 76.8958 - val_loss: 7662.4043 - val_root_mean_squared_error: 87.3689
# Epoch 93/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5855.2939 - root_mean_squared_error: 76.3116 - val_loss: 7376.0093 - val_root_mean_squared_error: 85.7115
# Epoch 94/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6097.7080 - root_mean_squared_error: 77.8855 - val_loss: 7530.1621 - val_root_mean_squared_error: 86.6057
# Epoch 95/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6034.8208 - root_mean_squared_error: 77.4768 - val_loss: 7541.2134 - val_root_mean_squared_error: 86.6663
# Epoch 96/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5857.9507 - root_mean_squared_error: 76.3326 - val_loss: 8187.9858 - val_root_mean_squared_error: 90.3241
# Epoch 97/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5820.3774 - root_mean_squared_error: 76.0849 - val_loss: 7722.0977 - val_root_mean_squared_error: 87.7065
# Epoch 98/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5783.9199 - root_mean_squared_error: 75.8477 - val_loss: 7804.0635 - val_root_mean_squared_error: 88.1666
# Epoch 99/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5939.9277 - root_mean_squared_error: 76.8628 - val_loss: 7980.5137 - val_root_mean_squared_error: 89.1640
# Epoch 100/100
# 767/767 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6155.1050 - root_mean_squared_error: 78.2290 - val_loss: 7596.1680 - val_root_mean_squared_error: 86.9825

# %%
# Calculate training loss
train_predictions = model.predict(X)
train_loss = np.mean((y - train_predictions.flatten())**2)

# Plot training loss
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss')  # Training loss during epochs
plt.axhline(y=train_loss, color='blue', linestyle='--', label='Final train Loss')  # Final training loss
plt.title('Loss on Training Data')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.show()

print(f"Final Training Loss (MSE): {train_loss}")
# Out:
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Final Training Loss (MSE): 5861.616722465541

# %%
rmse = np.sqrt(train_loss)
print("RMSE: ", rmse)
# Out:
# RMSE:  76.56119593152619

# %%
# Load sample submission file to maintain structure
sample_sub = pd.read_csv('sample_submission .csv')

# Prepare the test data (same as before)
X_test = test.drop(['No', 'Is', 'Ir', 'cbwd_NW', 'cbwd_SE', 'cbwd_cv'], axis=1)
X_test = np.expand_dims(X_test, axis=1)

# Make predictions
predictions = model.predict(X_test)
predictions = np.nan_to_num(predictions)

# Convert predictions to integers (if required by competition rules)
predictions = np.round(predictions).astype(int)

# Create submission dataframe with proper ID format
submission = pd.DataFrame({
    'row ID': test.index.strftime('%Y-%m-%d %H:%M:%S').str.replace(" 0", " ", regex=False),  # Fix hour formatting
    'pm2.5': predictions.flatten()
})

# Merge with sample submission to ensure identical structure
submission = sample_sub[['row ID']].merge(submission, on='row ID', how='left')

# Save submission
submission.to_csv('final_submission5.csv', index=False)
# Out:
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
